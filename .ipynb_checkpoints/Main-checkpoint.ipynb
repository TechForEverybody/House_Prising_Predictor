# %% [markdown]
# # dataFrame== consistof atributename and data in tabular form
# # splitData== split train and test data
# # remove Dependent Variable as Label and store in features
# # Convert into standard from after filling missing values
# # create model with statndard data and labels
#
# # for testing again same as above and then run model.predict only give preapared testing array
#
# # save model and retrive

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit,cross_val_score
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error
from joblib import dump,load

# %% [markdown]
# ## Code started

# %%
housing=pd.read_csv('./data/data.csv')

# %%
print(housing)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 501    0
# 502    0
# 503    0
# 504    0
# 505    0
# Name: CHAS, Length: 506, dtype: int64

# %%
housing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
35/506
# Out:
# 0.0691699604743083

# %%
# housing.hist(bins=50,figsize=(20,15))

# %% [markdown]
# ## Train Test Splitting

# %% [markdown]
# ## By Normal Coding

# %%
def split_data(data,train_ratio):
    np.random.seed(42)
    shuffed=np.random.permutation(len(data))
#     print(shuffed)
    train_size=int(len(data)*train_ratio)
#     print(train_size)
#     train_indices=data
    train_indices=shuffed[:train_size]
    test_indices=shuffed[train_size:]
#     return data[:train_size],data[train_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
# traindata,testdata=split_data(housing,0.80)

# %%
# traindata

# %%
# testdata

# %%
# housing['TAXRM']=housing['TAX']/housing['RM']

# %% [markdown]
# ## By Using sklearn

# %%
traindata,testdata=train_test_split(housing,test_size=0.2,random_state=42)

# %%
# traindata

# %%
# testdata

# %% [markdown]
# # for  equal boolean values

# %%
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
print(split.split(housing,housing['CHAS']))
for train_index,test_index in split.split(housing,housing['CHAS']):
    traindata=housing.loc[train_index]
    testdata=housing.loc[test_index]
# Out:
# <generator object BaseShuffleSplit.split at 0x000002C53749DE40>

# %%
traindata['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
testdata
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 342   0.02498   0.0   1.89     0  0.518  6.540   59.7  6.2669    1  422
# 379  17.86670   0.0  18.10     0  0.671  6.223  100.0  1.3861   24  666
# 223   0.61470   0.0   6.20     0  0.507  6.618   80.8  3.2721    8  307
# 219   0.11425   0.0  13.89     1  0.550  6.373   92.4  3.3633    5  276
# 48    0.25387   0.0   6.91     0  0.448  5.399   95.3  5.8700    3  233
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 88    0.05660   0.0   3.41     0  0.489  7.007   86.3  3.4217    2  270
# 466   3.77498   0.0  18.10     0  0.655  5.952   84.7  2.8715   24  666
# 52    0.05360  21.0   5.64     0  0.439  6.511   21.1  6.8147    4  243
# 121   0.07165   0.0  25.65     0  0.581  6.004   84.1  2.1974    2  188
# 218   0.11069   0.0  13.89     1  0.550  5.951   93.8  2.8893    5  276
#
#      PTRATIO       B  LSTAT  MEDV
# 342     15.9  389.96   8.65  16.5
# ...

# %% [markdown]
# # correlation

# %%
correlation_matrix=housing.corr()

# %%
correlation_matrix
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# ## Attribute PLotting

# %%
attributes=['MEDV','RM','ZN','LSTAT','CHAS']

# %%
scatter_matrix(housing[attributes],figsize=(20,15))
# Out:
# array([[<AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='RM'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
# ...

# %%
housing.plot(kind='scatter',x='RM',y='MEDV',alpha=0.8)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ## Trying New Attributes

# %%
housing_features=traindata.drop("MEDV",axis=1)
housing_labels=traindata['MEDV']

# %% [markdown]
# ## Filling MIssing Values

# %%
# for nune values delete rowo
# for none values delete column
# for none values fill mean median mode etc.

# %%
housing.dropna(subset=['RM'])
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing.drop(["RM"],axis=1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31     0  0.538  65.2  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07     0  0.469  78.9  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07     0  0.469  61.1  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18     0  0.458  45.8  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18     0  0.458  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...   ...    ...   ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93     0  0.573  69.1  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93     0  0.573  76.7  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93     0  0.573  91.0  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93     0  0.573  89.3  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93     0  0.573  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# ...

# %%
housing['RM'].fillna(housing['RM'].median())
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
housing_features.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279908
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712983
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.210000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630250
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
imputer=SimpleImputer(strategy='median')
imputer.fit(housing_features)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.21000e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
x=imputer.transform(housing_features)

# %%
x
# Out:
# array([[4.81900e-02, 8.00000e+01, 3.64000e+00, ..., 1.64000e+01,
#         3.92890e+02, 6.57000e+00],
#        [1.50100e-02, 8.00000e+01, 2.01000e+00, ..., 1.70000e+01,
#         3.90940e+02, 5.99000e+00],
#        [4.87141e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.96210e+02, 1.86800e+01],
#        ...,
#        [8.18700e-02, 0.00000e+00, 2.89000e+00, ..., 1.80000e+01,
#         3.93530e+02, 3.57000e+00],
#        [4.75237e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         5.09200e+01, 1.81300e+01],
#        [4.56000e-02, 0.00000e+00, 1.38900e+01, ..., 1.64000e+01,
#         3.92800e+02, 1.35100e+01]])

# %%
housing_train=pd.DataFrame(x,columns=housing_features.columns)

# %%
housing_train
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 0    0.04819  80.0   3.64   0.0  0.392  6.108  32.0  9.2203   1.0  315.0
# 1    0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440   4.0  280.0
# 2    4.87141   0.0  18.10   0.0  0.614  6.484  93.6  2.3053  24.0  666.0
# 3    0.18159   0.0   7.38   0.0  0.493  6.376  54.3  4.5404   5.0  287.0
# 4    0.30347   0.0   7.38   0.0  0.493  6.312  28.9  5.4159   5.0  287.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 399  3.53501   0.0  19.58   1.0  0.871  6.152  82.6  1.7455   5.0  403.0
# 400  7.05042   0.0  18.10   0.0  0.614  6.103  85.1  2.0218  24.0  666.0
# 401  0.08187   0.0   2.89   0.0  0.445  7.820  36.9  3.4952   2.0  276.0
# 402  4.75237   0.0  18.10   0.0  0.713  6.525  86.5  2.4358  24.0  666.0
# 403  0.04560   0.0  13.89   1.0  0.550  5.888  56.0  3.1121   5.0  276.0
#
#      PTRATIO       B  LSTAT
# 0       16.4  392.89   6.57
# 1       17.0  390.94   5.99
# ...

# %% [markdown]
# ## ScikitLearn design

# %% [markdown]
# ## CREATING PIPELINE

# %%
my_pipeline=Pipeline([('imputer',SimpleImputer(strategy="median")),('std_scaler',StandardScaler())])

# %%
housing_training=my_pipeline.fit_transform(housing_features)

# %%
housing_features
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %%
housing_training
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
housing_training.shape
# Out:
# (404, 13)

# %%
# model=LinearRegression()
model = RandomForestRegressor()
model.fit(housing_training,housing_labels)
# Out:
# RandomForestRegressor()

# %%
somedata=housing_features.iloc[:5]

# %%
somedata
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# 321     19.6  396.90   6.87
# 326     19.6  396.90   6.15

# %%
somelabels=housing_labels[:5]

# %%
somelabels
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: MEDV, dtype: float64

# %%
preparedata=my_pipeline.transform(somedata)

# %%
preparedata
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#         -0.24141041, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#         -0.97491834,  0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, -0.27288841, -1.0542567 ,
#          0.49865392, -1.3938808 ,  2.19312325, -0.65766683, -0.78557904,
#         -0.69277865,  0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, -0.27288841,  0.47919371,
#          0.28660512,  0.87020968, -0.68730678,  1.63579367,  1.50571521,
#          0.81196637,  0.44624347,  0.81480158],
#        [-0.42292925, -0.4898311 , -0.57719868, -0.27288841, -0.5573845 ,
#          0.13494109, -0.52225911,  0.37882487, -0.5429938 , -0.74402708,
#          0.52982668,  0.45343469, -0.81939807],
#        [-0.40786253, -0.4898311 , -0.57719868, -0.27288841, -0.5573845 ,
#          0.0450661 , -1.42222622,  0.79643404, -0.5429938 , -0.74402708,
# ...

# %%
x=model.predict(preparedata)

# %%
x
# Out:
# array([22.421, 25.273, 16.349, 23.383, 23.477])

# %% [markdown]
# ## Evaluation

# %%
housing_predictions=model.predict(housing_training)

# %%
housing_predictions
# Out:
# array([22.421, 25.273, 16.349, 23.383, 23.477, 16.706, 24.46 , 27.163,
#        10.182, 32.152, 15.39 , 18.367, 10.832, 33.973, 22.949, 13.953,
#        18.61 , 17.41 ,  6.94 , 20.359, 19.167, 16.879, 18.147, 27.723,
#        24.296, 24.744, 13.428, 21.005, 14.808, 27.753, 14.438, 17.869,
#        11.344, 13.27 , 20.777, 27.109, 23.627, 47.987, 32.996, 19.811,
#        22.338, 34.884, 37.055,  9.824, 20.103, 12.793, 21.828, 27.802,
#        23.275,  7.6  , 24.666, 23.149, 23.592, 30.602, 14.864, 37.666,
#        21.559, 25.357, 33.748, 17.862, 19.697, 19.862, 27.708, 20.952,
#        14.207, 31.753, 49.842, 14.654, 26.891, 34.828, 22.706, 35.905,
#        23.196, 10.078, 20.832, 27.478, 25.796, 15.43 , 16.278, 18.71 ,
#        30.936,  8.702, 19.408, 18.796, 25.626, 23.986, 30.18 , 24.831,
#        29.098, 16.275, 23.221, 29.696, 28.053, 20.021, 21.817, 34.654,
#        29.588, 19.43 , 23.224, 17.607, 12.594, 46.265, 20.334, 43.757,
# ...

# %%
housing_labels
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
#        ...
# 155    15.6
# 423    13.4
# 98     43.8
# 455    14.1
# 216    23.3
# Name: MEDV, Length: 404, dtype: float64

# %%
mean_squared_error_value=mean_squared_error(housing_labels,housing_predictions)

# %%
mean_squared_error_value
# Out:
# 1.3815248762376218

# %%
np.sqrt(mean_squared_error_value)
# Out:
# 1.1753828636821373

# %%
scores=cross_val_score(model,housing_training,housing_labels,scoring="neg_mean_squared_error",cv=10)

# %%
-scores
# Out:
# array([ 8.67384624,  8.04329024, 19.61606985,  6.17719461, 11.81323935,
#         7.06649615, 23.30109287, 10.44658585, 10.31308158, 10.14606715])

# %%
score=np.sqrt(-scores)

# %%
score
# Out:
# array([2.94513943, 2.83606951, 4.42900326, 2.48539627, 3.43703933,
#        2.6582882 , 4.82712056, 3.23211786, 3.21139869, 3.18528918])

# %%
score.mean()
# Out:
# 3.3246862275455435

# %%
score.std()
# Out:
# 0.7114477341948119

# %%
dump(model,'homepricepredictor.joblib')
# Out:
# ['homepricepredictor.joblib']

# %% [markdown]
# ## testing

# %%
test_features=testdata.drop('MEDV',axis=1)
test_labels=testdata['MEDV']

# %%
test_prepared=my_pipeline.transform(test_features)

# %%
test_prepared
# Out:
# array([[-0.44228927, -0.4898311 , -1.37640684, ..., -1.21003475,
#          0.38110555, -0.57309194],
#        [ 1.76329132, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.42050096,  1.24376169],
#        [-0.36938851, -0.4898311 , -0.74897749, ..., -0.50468552,
#          0.45343469, -0.71838488],
#        ...,
#        [-0.43875128,  0.45939847, -0.83049963, ..., -0.78682521,
#          0.45343469, -1.0394131 ],
#        [-0.43651996, -0.4898311 ,  2.08246124, ...,  0.29471027,
#          0.25301836,  0.20457123],
#        [-0.43169386, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.45343469,  0.70963717]])

# %%
test_predictions=model.predict(test_prepared)

# %%
test_predictions
# Out:
# array([24.933, 11.088, 25.689, 22.085, 18.472, 14.987, 19.93 , 14.326,
#        32.023, 40.829, 19.377, 11.62 , 25.232, 28.977, 19.444, 11.158,
#        31.282, 14.508, 23.781, 18.636, 20.522, 17.886, 17.353, 22.367,
#        18.671, 31.315, 16.149, 32.866,  8.65 , 33.144, 24.976, 21.371,
#        22.877, 11.114, 20.938, 11.097, 43.344, 24.062, 23.53 , 42.686,
#        24.095, 30.505, 20.603, 20.774, 19.211, 33.74 , 44.576, 20.105,
#        20.218, 21.387, 21.178, 14.436, 21.443, 14.457, 24.912, 32.951,
#        43.204, 28.815, 19.659, 20.807, 47.259,  9.25 , 19.123, 24.653,
#        14.553, 32.745, 20.078, 17.914, 19.272, 34.249, 25.423, 22.708,
#        21.226, 22.371, 34.995, 13.5  , 15.577, 20.043, 20.975, 21.493,
#        22.576, 21.255, 13.536, 22.839, 20.941, 21.069, 13.825, 21.36 ,
#        21.977, 23.377, 18.673, 27.162,  7.148, 26.675, 19.258, 29.174,
#        19.502, 30.963, 14.249, 26.744, 21.262, 20.386])

# %%
test_labels
# Out:
# 342    16.5
# 379    10.2
# 223    30.1
# 219    23.0
# 48     14.4
#        ...
# 88     23.6
# 466    19.0
# 52     25.0
# 121    20.3
# 218    21.5
# Name: MEDV, Length: 102, dtype: float64

# %%
mse=mean_squared_error(test_labels,test_predictions)

# %%
mse
# Out:
# 8.629501931372543

# %%
mae=mean_absolute_error(test_labels,test_predictions)

# %%
mae
# Out:
# 2.059401960784314

# %%
np.sqrt(mse)
# Out:
# 2.9376013908242458

# %% [markdown]
# ## Model Testing

# %%
model=load('./homepricepredictor.joblib')

# %%
model.predict([test_prepared[0]])
# Out:
# array([24.933])
